# %%
import sheap
from sheap.MainSheap import Sheapectral 
from sheap.Plotting.SheapPlot import SheapPlot
from sheap.spectra_readers import parallel_reader

# %%
from jax import config
config.update("jax_enable_x64", True)
from pathlib import Path
import glob

# %%
# %load_ext autoreload
# %autoreload 2

# %%
spectrum_dic = Path(sheap.__file__).resolve().parent / "SuportData" / "Spectrum"
files = glob.glob(f"{spectrum_dic}/*")

# %% [markdown]
# - Small example on how to use sheap, first we need to read the spectrums for this we use the function **parallel_reader**

# %%
coords,spectra,_ = parallel_reader(files,parallel=False) 
z = [0.161769,0.184366]
# Out:
# Doing the reading not parallel.

# %%
# coords,spectra,_ = parallel_reader([files[0]]) 
# z = [0.161769]

# %%
sheapspectral = Sheapectral(spectra,z=z,coords=coords)
# Out:
# extinction correction will be do it, change 'extinction_correction' to done if you want to avoid this step
# redshift correction will be do it, change 'redshift_correction' to done if you want to avoid this step

# %%
sheapspectral.quicklook(0)
# Out:
# <Axes: xlabel='Wavelength [Å]', ylabel='Flux [arb]'>

# %%
sheapspectral.build_region(6000,8000,n_broad=1)
# Out:
# added OP template

# %%
sheapspectral.fit_region(num_steps_list=[1000,1000])
# Out:
# Fitting 2 spectra
# STEP1
# learning_rate: 0.1 num_steps: 1000 non_optimize_in_axis: 3
# STEP2
# learning_rate: 0.01 num_steps: 1000 non_optimize_in_axis: 4
# running uncertainty

# %%
sheapspectral.params_dict
# Out:
# {'logFWHM_feop_21_fe': 0,
#  'shift_feop_21_fe': 1,
#  'scale_feop_21_fe': 2,
#  'amplitude_OIa_1_broad': 3,
#  'center_OIa_1_broad': 4,
#  'width_OIa_1_broad': 5,
#  'amplitude_OIb_1_broad': 6,
#  'center_OIb_1_broad': 7,
#  'width_OIb_1_broad': 8,
#  'amplitude_OIc_1_broad': 9,
#  'center_OIc_1_broad': 10,
#  'width_OIc_1_broad': 11,
#  'amplitude_OId_1_broad': 12,
#  'center_OId_1_broad': 13,
#  'width_OId_1_broad': 14,
#  'amplitude_OIa_1_narrow': 15,
#  'center_OIa_1_narrow': 16,
#  'width_OIa_1_narrow': 17,
#  'amplitude_OIb_1_narrow': 18,
#  'center_OIb_1_narrow': 19,
#  'width_OIb_1_narrow': 20,
#  'amplitude_SIIa_1_narrow': 21,
#  'center_SIIa_1_narrow': 22,
#  'width_SIIa_1_narrow': 23,
#  'amplitude_SIIb_1_narrow': 24,
#  'center_SIIb_1_narrow': 25,
#  'width_SIIb_1_narrow': 26,
#  'amplitude_OIIc_1_narrow': 27,
#  'center_OIIc_1_narrow': 28,
#  'width_OIIc_1_narrow': 29,
#  'amplitude_NIIb_1_narrow': 30,
#  'center_NIIb_1_narrow': 31,
#  'width_NIIb_1_narrow': 32,
#  'amplitude_NIIa_1_narrow': 33,
#  'center_NIIa_1_narrow': 34,
#  'width_NIIa_1_narrow': 35,
#  'amplitude_HeIf_1_narrow': 36,
#  'center_HeIf_1_narrow': 37,
#  'width_HeIf_1_narrow': 38,
#  'amplitude_HeIf_1_broad': 39,
#  'center_HeIf_1_broad': 40,
#  'width_HeIf_1_broad': 41,
#  'amplitude_HeIg_1_narrow': 42,
#  'center_HeIg_1_narrow': 43,
#  'width_HeIg_1_narrow': 44,
#  'amplitude_HeIg_1_broad': 45,
#  'center_HeIg_1_broad': 46,
#  'width_HeIg_1_broad': 47,
#  'amplitude_HeIh_1_narrow': 48,
#  'center_HeIh_1_narrow': 49,
#  'width_HeIh_1_narrow': 50,
#  'amplitude_HeIh_1_broad': 51,
#  'center_HeIh_1_broad': 52,
#  'width_HeIh_1_broad': 53,
#  'amplitude_Halpha_1_narrow': 54,
#  'center_Halpha_1_narrow': 55,
#  'width_Halpha_1_narrow': 56,
#  'amplitude_Halpha_1_broad': 57,
#  'center_Halpha_1_broad': 58,
#  'width_Halpha_1_broad': 59,
#  'index_powerlaw_0_continuum': 60,
#  'scale_powerlaw_0_continuum': 61}

# %%
sheapspectral.uncertainty_params[0]
# Out:
# Array([3.18473928e+03, 3.18473928e+03, 7.40453794e-19, 6.05542154e-18,
#        3.18473928e+03, 3.18473928e+03, 5.41939233e-18, 3.18473928e+03,
#        3.18473928e+03, 5.30273692e-18, 8.89263871e+00, 9.12739597e+00,
#        7.79457875e-18, 6.72013173e+01, 6.87037348e+01, 9.74693772e-18,
#        3.18473928e+03, 3.18473928e+03, 9.53469574e-18, 3.18473928e+03,
#        3.18473928e+03, 2.87960984e-17, 2.24233591e-01, 2.58037680e-01,
#        2.09484554e-17, 3.33156934e-01, 3.19321457e-01, 9.75801833e-18,
#        3.18473928e+03, 3.18473928e+03, 2.12416867e-17, 3.18473928e+03,
#        3.18473928e+03, 3.61004450e-17, 3.18473928e+03, 3.18473928e+03,
#        1.06664200e-17, 3.18473928e+03, 3.18473928e+03, 5.98228533e-18,
#        3.18473928e+03, 3.18473928e+03, 1.08695566e-17, 3.18473928e+03,
#        3.18473928e+03, 6.35365200e-18, 3.18473928e+03, 3.18473928e+03,
#        1.55189689e-17, 3.18473928e+03, 3.18473928e+03, 9.03462782e-18,
#        4.86608204e+01, 4.47176969e+01, 1.39183204e-17, 1.29068837e+00,
#        1.27089438e+00, 1.45361225e-17, 5.12225200e-01, 4.84016965e-01,
#        4.78332987e-02, 1.60988985e-16], dtype=float64)
