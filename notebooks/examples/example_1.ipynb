# %%
from jax import config
config.update("jax_enable_x64", True)
from pathlib import Path
import glob

# %%
import sheap
from sheap.MainSheap import Sheapectral 
from sheap.Plotting.SheapPlot import SheapPlot
from sheap.spectra_readers import parallel_reader

# %%
# %load_ext autoreload
# %autoreload 2

# %%
spectrum_dic = Path(sheap.__file__).resolve().parent / "SuportData" / "Spectrum"
files = glob.glob(f"{spectrum_dic}/*")

# %% [markdown]
# - Small example on how to use sheap, first we need to read the spectrums for this we use the function **parallel_reader**

# %%
coords,spectra,_ = parallel_reader(files) 
z = 0.161769

# %%
sheapspectral = Sheapectral(spectra,z=z,coords=coords)
# Out:
# extinction correction will be do it, change 'extinction_correction' to done if you want to avoid this step
# redshift correction will be do it, change 'redshift_correction' to done if you want to avoid this step

# %%
sheapspectral.quicklook(0)
# Out:
# <Axes: xlabel='Wavelength [Å]', ylabel='Flux [arb]'>

# %%
sheapspectral.build_region(6000,8000,n_broad=1)
# Out:
# added OP template

# %%
sheapspectral.

# %%
sheapspectral.fit_region(num_steps_list=[1000,1000])
# Out:
# Fitting 1 spectra
# STEP1
# learning_rate: 0.1 num_steps: 1000 non_optimize_in_axis: 3
# E0515 07:51:29.858374 2312554 cuda_blas.cc:196] failed to create cublas handle: the resource allocation failed
# E0515 07:51:29.858430 2312554 cuda_blas.cc:199] Failure to initialize cublas may be due to OOM (cublas needs some free memory when you initialize it, and your deep-learning framework may have preallocated more than its fair share), or may be because this binary was not built with support for the GPU in your machine.
# E0515 07:51:29.858483 2312554 pjrt_stream_executor_client.cc:3085] Execution of replica 0 failed: INTERNAL: Unable to get Blas support
# Fitting failed
# Traceback (most recent call last):
#   File "/home/favila/smbh_mass/sheap/sheap/RegionFitting/RegionFitting.py", line 210, in _fit
#     params, loss = minimizer(
#                    ^^^^^^^^^^
#   File "/home/favila/smbh_mass/sheap/sheap/FunctionsMinimize/MasterMinimizer.py", line 110, in __call__
#     return vmap_optimize_model(initial_params,y,x,yerror,constraints,*self.default_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/api.py", line 992, in vmap_f
#     out_flat = batching.batch(
#                ^^^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/linear_util.py", line 193, in call_wrapped
#     ans = self.f(*args, **dict(self.params, **kwargs))
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/favila/smbh_mass/sheap/sheap/FunctionsMinimize/MasterMinimizer.py", line 182, in optimize_model
#     params, opt_state, loss = step(params, opt_state, xs, y)
#                               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/traceback_util.py", line 180, in reraise_with_filtered_traceback
#     return fun(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/pjit.py", line 338, in cache_miss
#     outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked = _python_pjit_helper(
#                                                                 ^^^^^^^^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/pjit.py", line 188, in _python_pjit_helper
#     out_flat = pjit_p.bind(*args_flat, **p.params)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/core.py", line 2803, in bind
#     return self.bind_with_trace(top_trace, args, params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/core.py", line 442, in bind_with_trace
#     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/interpreters/batching.py", line 491, in process_primitive
#     val_out, dim_out = batched_primitive(vals_in, dims_in, **params)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/pjit.py", line 1970, in _pjit_batcher
#     vals_out = pjit_p.bind(
#                ^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/core.py", line 2803, in bind
#     return self.bind_with_trace(top_trace, args, params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/core.py", line 442, in bind_with_trace
#     out = trace.process_primitive(self, map(trace.full_raise, args), params)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/core.py", line 955, in process_primitive
#     return primitive.impl(*tracers, **params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/pjit.py", line 1738, in _pjit_call_impl
#     return xc._xla.pjit(
#            ^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/pjit.py", line 1714, in call_impl_cache_miss
#     out_flat, compiled = _pjit_call_impl_python(
#                          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/pjit.py", line 1668, in _pjit_call_impl_python
#     return compiled.unsafe_call(*args), compiled
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/profiler.py", line 333, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/home/favila/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py", line 1287, in __call__
#     results = self.xla_executable.execute_sharded(input_bufs)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# jaxlib.xla_extension.XlaRuntimeError: INTERNAL: Unable to get Blas support
# ---------------------------------------------------------------------------
# XlaRuntimeError                           Traceback (most recent call last)
# File ~/smbh_mass/sheap/sheap/RegionFitting/RegionFitting.py:210, in RegionFitting._fit(self, norm_spec, model, initial_params, tied, learning_rate, weighted, num_steps, non_optimize_in_axis)
#     209 try:
# --> 210     params, loss = minimizer(
#     211         initial_params,
#     212         *norm_spec.transpose(1, 0, 2),
#     213         self.constraints
#     214     )
#     215 except Exception as e:
#
# File ~/smbh_mass/sheap/sheap/FunctionsMinimize/MasterMinimizer.py:110, in MasterMinimizer.__call__(self, initial_params, y, x, yerror, constraints, learning_rate, num_steps, optimizer, non_optimize_in_axis, list_dependencies)
#     108 vmap_optimize_model = vmap(self.optimize_model,in_axes=optimize_in_axis, out_axes=0)
# --> 110 return vmap_optimize_model(initial_params,y,x,yerror,constraints,*self.default_args)
#
#     [... skipping hidden 3 frame]
#
# File ~/smbh_mass/sheap/sheap/FunctionsMinimize/MasterMinimizer.py:182, in MasterMinimizer.minimization_function.<locals>.optimize_model(initial_params, xs, y, y_uncertainties, constraints, parsed_dependencies, learning_rate, num_steps, optimizer, verbose)
#     181 for step_num in range(num_steps):
# --> 182     params, opt_state, loss = step(params, opt_state, xs, y)
#     183     loss_history.append(loss)
#
#     [... skipping hidden 14 frame]
#
# File ~/miniforge3/envs/jax/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:1287, in ExecuteReplicated.__call__(self, *args)
#    1286 else:
# -> 1287   results = self.xla_executable.execute_sharded(input_bufs)
#    1289 if dispatch.needs_check_special():
#
# XlaRuntimeError: INTERNAL: Unable to get Blas support
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 sheapspectral.fit_region(num_steps_list=[1000,1000])
#
# File ~/smbh_mass/sheap/sheap/MainSheap.py:180, in Sheapectral.fit_region(self, num_steps_list, add_step, tied_fe)
#     177 self.fitting_rutine = self.builded_region(add_step = add_step,tied_fe = tied_fe,num_steps_list = num_steps_list)
#     178 fittingclass= RegionFitting(self.fitting_rutine)
#     179 params,uncertainty_params,outer_limits,inner_limits,loss,mask,step,params_dict,initial_params,profile_params_index_list,profile_functions,max_flux,profile_names,complex_region \
# --> 180     = fittingclass(spectra, do_return = True) #runmodel()?
#     181 self.outer_limits  = outer_limits
#     182 self.inner_limits = inner_limits
#
# File ~/smbh_mass/sheap/sheap/RegionFitting/RegionFitting.py:166, in RegionFitting.__call__(self, spectra, inner_limits, outer_limits, force_cut, exp_factor, do_return, sigma_params)
#     164     print(key.upper())
#     165     #step #step is a dictionary so it can take all the parameters directly to fit
# --> 166     params, loss = self._fit(norm_spec,self.model,params,**step)
#     167     uncertainty_params = jnp.zeros_like(params)
#     168 if sigma_params:
#
# File ~/smbh_mass/sheap/sheap/RegionFitting/RegionFitting.py:217, in RegionFitting._fit(self, norm_spec, model, initial_params, tied, learning_rate, weighted, num_steps, non_optimize_in_axis)
#     215 except Exception as e:
#     216     logger.exception("Fitting failed")
# --> 217     raise RuntimeError(f"Fitting error: {e}")
#     218 return params, loss
#
# RuntimeError: Fitting error: INTERNAL: Unable to get Blas support
